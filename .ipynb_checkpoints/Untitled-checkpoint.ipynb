# %%
from ImageRegression import train_model
train_model(dataset_id='alexrothmaier/regression-dataset-baseline',
            name = 'baseline',
            value_column_name='fill_level',
            test_split=0.2,
            output_dir='./results',
            num_train_epochs=10,
            learning_rate=1e-4)
# Out:
# Using the latest cached version of the dataset since alexrothmaier/regression-dataset-baseline couldn't be found on the Hugging Face Hub
# WARNING:datasets.load:Using the latest cached version of the dataset since alexrothmaier/regression-dataset-baseline couldn't be found on the Hugging Face Hub
# ---------------------------------------------------------------------------
# InvalidConfigName                         Traceback (most recent call last)
# Cell In[1], line 2
#       1 from ImageRegression import train_model
# ----> 2 train_model(dataset_id='alexrothmaier/regression-dataset-baseline',
#       3             data_dir = 'data/baseline',
#       4             value_column_name='fill_level',
#       5             test_split=0.2,
#       6             output_dir='./results',
#       7             num_train_epochs=10,
#       8             learning_rate=1e-4)
#
# ...

# %%
train_model(dataset_id='alexrothmaier/regression-dataset-combined',
            value_column_name='fill_level_mean_naive',
            test_split=0.2,
            output_dir='./results',
            num_train_epochs=10,
            learning_rate=1e-4)
